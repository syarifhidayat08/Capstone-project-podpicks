# %%
import pandas as pd
import numpy as np

import json
import requests
import urllib.parse

import spotipy.util as util
import spotipy.util as util

# %%
client_id = '07a0800fd29f4f178958d2ed249b24c1'         #<----------------- YOUR ID HERE
    
client_secret = '3ffba6a360d943eca14a252927d738f4'       #<----------------- YOUR SECRET HERE

username = 'SharifHidayat'                                #<----------------- YOUR USERNAME HERE

scope = 'playlist-modify-public playlist-modify'

redirect_uri = 'http://localhost:8080/'

token = util.prompt_for_user_token(username=username, 
                                   scope=scope, 
                                   client_id=client_id,   
                                   client_secret=client_secret,     
                                   redirect_uri=redirect_uri)

# %%
# PERFORM THE QUERY

id_list = []
name_list = []                                         # create empty lists to hold data
desc_list = []

type = 'show'    
market  = 'ID'
limit = 100                                             # assign variables for search query
offset = 0                                             # start offset at 0


more_runs = 1                                          # instantiate conditional variables
counter = 0  

                                                            # max offset is 2000 including limit
while((offset <= 1950) & (counter <= more_runs)):           # while loop to run with conditional variables



    query = f'{endpoint_url}'
    query += f'&q={search}'
    query += f'&type={type}'
    query += f'&offset={offset}'                       # format search query with assigned variables
    query += f'&market={market}'
    query += f'&limit={limit}'


    response = requests.get(query,                                           # get request
                   headers={"Content-Type":"application/json", 
                            "Authorization":f"Bearer {token}"})  
    json_response = response.json()                                           # as a json file


    for i in range(len(json_response['shows']['items'])):                      # loop through json

        id_list.append(json_response['shows']['items'][i]['id'])               # pull out info from json
        name_list.append(json_response['shows']['items'][i]['name'])           # into empty lists
        desc_list.append(json_response['shows']['items'][i]['description'])
        
        
    more_runs = (json_response['shows']['total'] // 50 )            # how many more runs of 50 are needed?       
        
    counter += 1                                                    # increase conditional counter by 1
    
    offset = offset + 50                                            # increase offset by 50

                                                                    # rinse and repeat!
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[81], line 35
#      29 response = requests.get(query,                                           # get request
#      30                headers={"Content-Type":"application/json",
#      31                         "Authorization":f"Bearer {token}"})
#      32 json_response = response.json()                                           # as a json file
# ---> 35 for i in range(len(json_response['shows']['items'])):                      # loop through json
#      37     id_list.append(json_response['shows']['items'][i]['id'])               # pull out info from json
#      38     name_list.append(json_response['shows']['items'][i]['name'])           # into empty lists
#
# KeyError: 'shows'

# %%
search = 'podcast indonesia'
endpoint_url = "https://api.spotify.com/v1/search?"
id_list = []
name_list = []                                         # create empty lists to hold data
desc_list = []
type = 'shows'    
market  = 'ID'
limit = 50                                             # assign variables for search query
offset = 5                                             # start offset at 0
more_runs = 1                                          # instantiate conditional variables
counter = 0

# %%
show_list = list(podcasts['id'])

# %%
# PERFORM THE QUERY

show_id_list = []                                       # create empty lists to hold data
id_list = []
dur_list = []
date_list = []
name_list = []
desc_list = []

for show_id in show_list:                               # iterate through every show in show_list
    
    more_runs = 1                                       # instantiate conditional variables
    counter = 0    
    
    id = show_id                                        # assign variables for search query
    type = 'episodes'
    market  = 'US'                                      # start the offset at 0
    limit = 50
    offset = 0                                

                                                             # max offset is 2000 including limit
    while((offset <= 1950) & (counter <= more_runs)):        # while loop to run with conditional variables
    
        endpoint_url = f"https://api.spotify.com/v1/shows/{id}/episodes?"

        query = f'{endpoint_url}'
        query += f'&q={search}'                              # format the query with assigned variables
        query += f'&type={type}'
        query += f'&offset={offset}'
        query += f'&market={market}'
        query += f'&limit={limit}'

        response = requests.get(query,                                      # send a get request
                       headers={"Content-Type":"application/json", 
                                "Authorization":f"Bearer {token}"})
        json_response = response.json()                                     # get response as a json file
        

        offset = offset + 50                                     # increase the offset by 50
        counter += 1                                             # increase the counter by 1
        

        if next(iter(json_response)) != 'error':                 # if there wasn't any errors append data
        
            for i in range(len(json_response['items'])):                        # loop through json

                show_id_list.append(show_id)
                id_list.append(json_response['items'][i]['id'])                 # pull out info from json
                dur_list.append(json_response['items'][i]['duration_ms'])       # append into empty lists
                date_list.append(json_response['items'][i]['release_date'])    
                name_list.append(json_response['items'][i]['name'])
                desc_list.append(json_response['items'][i]['description'])
                
            more_runs = (json_response['total'] // 50 )              # how many more runs of 50 are needed?  
        
        else:                                                   # if there was an error exit the while loop                    
            offset = 1000000
            print(json_response, ' for show id: ', show_id)     # print any show_ids that gave errors
# Out:
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  0AcY8I3TDX7c8kmqmqlMJ2
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  1ujNwiEVTgHtgpc9C6wOJ8
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  3aT6T1fdGuethhKscYVjrh
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  0TYJf39ToQKqcwsQtSJWPj
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  4WZXqq02qRdkUVdE5pdAgy
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  0pjnMwu6LH17z68InllA47
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  7BFkEXebbYAX3H92OZCU5u
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  0Q6vac5nE7qHtCGZamljqo
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  3vSglOZOziYzkkAobCMDbt
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  2euf1xAs7dwugnnldoYlit
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  51KNGaeh2HLz9sAg6kOnOr
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  66LN27a5B0sdqvmEIYgQui
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  5ulQOnHy1TaYDxtIv39eMJ
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  2sKX8Y9xCoWjxjnlJ0apVj
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  36dsobu7nnQd7pQlYw4i7R
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  4oawdLrtHLNorBFfqv8jdG
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  1lDSeElBxDdcWgDT7FPo2Y
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  4GDjoFkF8V2czL3cjDPgt3
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  6m9mRmu4oW2rzM3MWeJsis
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  2DJQHxIx6KWZAEFbGwwGGy
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  0v6VJVCstzxalh9gtyZrUs
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  6QMUNSyjktBKSNce41iNKO
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  40hLugRo2TeSNWARgv7hI9
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  7mxIJvLluP23JsVoRhYYvd
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  7pbXq51gLNZkg0sEvyzy70
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  6qJS8qZ7qIVjylx4FzX0u2
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  6EYU5Kk6Jce2SvAJOVuecf
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  79gH11TZZAGgKBCvfBkqrT
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  7eOCnlo0XyYJFSPl0k5yGX
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  4xNP52saYfElMIRAU2ZzkM
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  42a866DbctwqZjgqWOFdig
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  1ppv3AASUDFwsBwwJt93ss
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  3rV4ImHExDk5LZMt13MHmR
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  1EmXp6kJlK2sdeMzJYQFcz
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  2pcwhQGSwgS8naf0b6iTDQ
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  2AS8DFFHFFu7ZxyOJGV4ma
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  6fi8NJn0oJxYMeXEcnrosy
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  40ZmMsh6nb4oJbLLpbi8IJ
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  1BMkl9YuW7Zrut091G6wkN
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  3rATR06SISkZq3yZMTbZ8E
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  5c81OD8OgRLoyMlBaq2beQ
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  4pnwABfgNrSOR9mXjHY4Dr
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  66fzfFWZcagvuOvLKVuS5x
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  6wiVqkSKzq1SqQVT0W8RZ1
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  3hgt6ABhI7DWhPB4q7Xm9x
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  0gmvP13FFOxzVfCH9IGczK
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  68ACMCh1RyOCGCPtKNMZ2z
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  04q9e4rVBl8kCOMTV55hLp
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  3wbiYt0BrARHEZtrvWtBqi
# {'error': {'status': 404, 'message': 'Resource not found'}}  for show id:  0KzlCenlaQ8LlW8pwp3pM3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[85], line 33
#      30 query += f'&market={market}'
#      31 query += f'&limit={limit}'
# ---> 33 response = requests.get(query,                                      # send a get request
#      34                headers={"Content-Type":"application/json",
#      35                         "Authorization":f"Bearer {token}"})
#      36 json_response = response.json()                                     # get response as a json file
#      39 offset = offset + 50                                     # increase the offset by 50
#
# File d:\Scraping\.conda\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File d:\Scraping\.conda\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File d:\Scraping\.conda\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File d:\Scraping\.conda\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File d:\Scraping\.conda\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File d:\Scraping\.conda\Lib\site-packages\urllib3\connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File d:\Scraping\.conda\Lib\site-packages\urllib3\connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     464 try:
#     465     # Trigger any extra validation we need to do.
#     466     try:
# --> 467         self._validate_conn(conn)
#     468     except (SocketTimeout, BaseSSLError) as e:
#     469         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File d:\Scraping\.conda\Lib\site-packages\urllib3\connectionpool.py:1099, in HTTPSConnectionPool._validate_conn(self, conn)
#    1097 # Force connect early to allow us to validate the connection.
#    1098 if conn.is_closed:
# -> 1099     conn.connect()
#    1101 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1102 if not conn.is_verified and not conn.proxy_is_verified:
#
# File d:\Scraping\.conda\Lib\site-packages\urllib3\connection.py:653, in HTTPSConnection.connect(self)
#     650 # Remove trailing '.' from fqdn hostnames to allow certificate validation
#     651 server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 653 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     654     sock=sock,
#     655     cert_reqs=self.cert_reqs,
#     656     ssl_version=self.ssl_version,
#     657     ssl_minimum_version=self.ssl_minimum_version,
#     658     ssl_maximum_version=self.ssl_maximum_version,
#     659     ca_certs=self.ca_certs,
#     660     ca_cert_dir=self.ca_cert_dir,
#     661     ca_cert_data=self.ca_cert_data,
#     662     cert_file=self.cert_file,
#     663     key_file=self.key_file,
#     664     key_password=self.key_password,
#     665     server_hostname=server_hostname_rm_dot,
#     666     ssl_context=self.ssl_context,
#     667     tls_in_tls=tls_in_tls,
#     668     assert_hostname=self.assert_hostname,
#     669     assert_fingerprint=self.assert_fingerprint,
#     670 )
#     671 self.sock = sock_and_verified.socket
#     673 # Forwarding proxies can never have a verified target since
#     674 # the proxy is the one doing the verification. Should instead
#     675 # use a CONNECT tunnel in order to verify the target.
#     676 # See: https://github.com/urllib3/urllib3/issues/3267.
#
# File d:\Scraping\.conda\Lib\site-packages\urllib3\connection.py:806, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     803     if is_ipaddress(normalized):
#     804         server_hostname = normalized
# --> 806 ssl_sock = ssl_wrap_socket(
#     807     sock=sock,
#     808     keyfile=key_file,
#     809     certfile=cert_file,
#     810     key_password=key_password,
#     811     ca_certs=ca_certs,
#     812     ca_cert_dir=ca_cert_dir,
#     813     ca_cert_data=ca_cert_data,
#     814     server_hostname=server_hostname,
#     815     ssl_context=context,
#     816     tls_in_tls=tls_in_tls,
#     817 )
#     819 try:
#     820     if assert_fingerprint:
#
# File d:\Scraping\.conda\Lib\site-packages\urllib3\util\ssl_.py:440, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     438 if ca_certs or ca_cert_dir or ca_cert_data:
#     439     try:
# --> 440         context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     441     except OSError as e:
#     442         raise SSLError(e) from e
#
# KeyboardInterrupt:

# %%
all_episodes = pd.DataFrame()

all_episodes['show_id'] = show_id_list
all_episodes['episode_id'] = id_list
all_episodes['length(ms)'] = dur_list
all_episodes['date'] = date_list
all_episodes['episode_name'] = name_list
all_episodes['description'] = desc_list 
fmap = podcasts.groupby('id')['name'].apply(list).to_dict()
all_episodes['show_id'] = all_episodes['show_id'].map(fmap)
all_episodes.rename(columns = {'show_id':'show_name'}, inplace = True)
all_episodes['show_name'] = all_episodes['show_name'].str[0]
all_episodes
# Out:
# Empty DataFrame
# Columns: [show_name, episode_id, length(ms), date, episode_name, description]
# Index: []

# %%
podcasts.to_csv('podcast_indo_episode.csv', index=False)
